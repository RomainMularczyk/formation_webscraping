# %%
def extract_text_from_pdf():
    
    import PyPDF2
    import os
        
    files = os.listdir()
    
    pdfWriter = PyPDF2.PdfFileWriter()
    
    for file in files:
        
        pdfFile = open(file, "rb")
        pdfReader = PyPDF2.PdfFileReader(pdfFile)

        for p in range(pdfReader.numPages):
            pageObj = pdfReader.getPage(p)
            print(pageObj.extractText())
            pdfWriter.addPage(pageObj)
            
                
    pdfOutputFile = open("combinedfiles.pdf", "wb")
    pdfWriter.write(pdfOutputFile)
    pdfOutputFile.close()

# %%
extract_text_from_pdf()
# Out:
# Le4mars2020
# Enquêtesdelastatistiquepubliqueabordantlapra-
# tiquedusport
# Voiciunelistenonexhaustived'enquêtesdelastatistiquepubliquequiontabordé
# aumoinsàl'occasiond'unequestionlespratiquesphysiquesetsportives.Ils'agit
# d'unelisteévolutive,n'hésitezpasàenvoyeruncourrielàlouis.david@mshb.frpour
# suggérerunajout.
# DonnéesdisponiblesvialeportailQuételet-Progedo
#
# 1967:EnquêteLoisirs-INSEE
#
# 1974-1975:Enquêteemploidutemps-INSEE
#
# 1977:Lesstructuresdel'opinion-CEA
#
# 1978:Lesstructuresdel'opinion-CEA
#
# 1981-1982:Transport-INSEE
#
# 1985-1986:Emploidutemps-INSEE
#
# 1986:Lesstructuresdel'opinion-Jean-PierrePagès,DémosthèneAgra˝otis
#
# 1990-1992:AnalysedescomportementssexuelsenFrance-INED
#
# 1991:Lesstructuresdel'opinion-Jean-PierrePagès,DémosthèneAgra˝otis
#
# 1993-1994:Passageàl'âgeadulte-INED
#
# mai1995:Enquêtepermanentesurlesconditionsdeviedesménages,partie
# variable:vacancesàdomicile-INSEE
#
# 1995:Enquêteinterrégionaledesphénomènespolitiques-OIP
#
# 1996:Enquêteinterrégionaledesphénomènespolitiques-OIP
#
# janvier1997:Enquêtepermanentesurlesconditionsdeviedesménages,
# partievariable:travailetmodesdevie-INSEE
#
# 1997:Baromètrenucléaire-Jean-PierrePagès,DémosthèneAgra˝otis
#
# 1998:Comportementsfaceauxrisquesetàl'avenir-Enquêtecomplémentaire
# àl'enquêtePatrimoine-INSEE
#
# 1998:Handicaps,incapacités,dépendance:personnesvivanteninstitutions
# -INSEE
#
# 1998-1999:Emploidutemps-INSEE
#
# 1999:Handicaps,incapacités,dépendance:personnesvivantàdomicile-
# INSEE
#
# 2000:Baromètred'opiniondelaDREES-DREES-MinistèredelaSanté
# 1
#
#
# 2000:Handicaps,incapacités,dépendance:personnesvivanteninstitutions
# -INSEE
#
# octobre2000:Enquêtepermanentesurlesconditionsdeviedesménages,
# partievariable:lestransmissionsfamiliales-INSEE
#
# mai2001:Enquêtepermanentesurlesconditionsdeviedesménages,partie
# variable:comportementsvisàvisdelasanté-INSEE
#
# 2001:Baromètred'opiniondelaDREES-DREES-MinistèredelaSanté
#
# 2001:Enquêteinterrégionaledesphénomènespolitiques-OIP
#
# 2001:Handicaps,incapacités,dépendance:personnesenmilieucarcéral-
# INSEE
#
# 2001-2002:Enquêtenationalesurlasantéauprèsdesélèvesscolarisésen
# classedeCM2-DREES-MinistèredelaSanté
#
# 2002:Baromètred'opiniondelaDREES-DREES-MinistèredelaSanté
#
# octobre2002:Enquêtepermanentesurlesconditionsdeviedesménages,
# partievariable:vieassociative-INSEE
#
# 2002-2008:Universcultureldesenfantsetdesadolescents-DEPS
#
# mai2003:Enquêtepermanentesurlesconditionsdeviedesménages,partie
# variable:participationàlavieculturelleetsportive-INSEE
#
# 2003-2004:Enquêtenationalesurlasantéauprèsdesélèvesscolarisésen
# classede3ème-DREES-MinistèredelaSanté
#
# 2004:InformationetVieQuotidienne-INSEE
#
# 2004:Baromètred'opiniondelaDREES-DREES-MinistèredelaSanté
#
# octobre2004:Enquêtepermanentesurlesconditionsdeviedesménages,
# partievariable:vacances-INSEE
#
# 2004-2005:Enquêtenationalesurlasantéauprèsdesélèvesscolarisésen
# classedeCM2-DREES-MinistèredelaSanté
#
# 2005:Baromètred'opiniondelaDREES-DREES-MinistèredelaSanté
#
# 2005-2006:Enquêtenationalesurlasantéauprèsdesélèvesscolarisésen
# classedegrandesectiondematernelle-DREES-MinistèredelaSanté
#
# 2006:InformationetVieQuotidienne-Martinique-INSEE
#
# 2006:Baromètred'opiniondelaDREES-DREES-MinistèredelaSanté
#
# 2006-2007:Parcoursetpro˝lsdesmigrants-DREES-MinistèredelaSanté
#
# 2007:InternationalSocialSurveyProgramme-EnquêteFrance-Loisirset
# sportI-ISSP
#
# 2007:InformationetVieQuotidienne-Réunion-INSEE
#
# 2007:EnquêteEmploidanslesDOM-INSEE
#
# 2008:Trajectoiresetorigines,enquêtesurladiversitédespopulationsen
# 2
#
# France-INSEE
#
# 2008:Pratiquesculturellesdesfrançais-DEPS-MinistèredelaCulture
#
# 2008:InformationetVieQuotidienne-Guadeloupe-INSEE
#
# 2008:EnquêteHandicapSanté-Voletaidantsinformels-DREES-Ministère
# delaSanté
#
# 2008:EnquêteHandicapSanté-INSEE
#
# 2008:Enquêtenationaletransportsetdéplacements-SOeS-Ministèredes
# Transports
#
# 2008-2009:Enquêtenationalesurlasantéauprèsdesélèvesscolarisésen
# classede3ème-DREES-MinistèredelaSanté
#
# 2009:Statistiquessurlesressourcesetlesconditionsdevie-INSEE
#
# 2009-2010:Emploidutemps-INSEE
#
# 2010:EnquêtesurlesPratiquesPhysiquesetSportives-CNDS/Direction
# dessports-INPES-MEOS
#
# 2010:LavieassociativeenFrance-DREES-MinistèredelaSanté
#
# 2011:EnquêteLongitudinalesurl'IntégrationdesPrimo-Arrivants,vague2
# -DSED-Ministèredel'Intérieur
#
# 2011:InformationetVieQuotidienne-Réunion-INSEE
#
# 2011:InformationetVieQuotidienne-Guyane-INSEE
#
# 2011:InformationetVieQuotidienne-Mayotte-INSEE
#
# 2011:InternationalSocialSurveyProgramme-EnquêteFrance-SantéI-
# ISSP
#
# 2012:Enquêtesurlasantéetlaprotectionsociale(ESPS)-IRDES
#
# 2012:FrenchElectoralStudy-CEE
#
# 2012:Laviedeuxansaprèsundiagnosticdecancer-INCa-INSERM
#
# 2012:Statistiquessurlesressourcesetlesconditionsdevie-INSEE
#
# 2012-2013:Enquêtenationalesurlasantéauprèsdesélèvesscolarisésen
# classedegrandesectiondematernelle-DREES-MinistèredelaSanté
#
# 2013:Conditionsdeviedesétudiants(CdV)-Observatoiredelavieétu-
# diante
#
# 2013:EnquêteEmploiencontinu(versionFPR)-INSEE
#
# 2013:Dynamiquesdemobilisation:comprendrelaformationdeschoixélec-
# toraux-vague1-EquipeELIPSS
#
# 2013:Situationdecouple,intentionsdeféconditéetopinionssurlafamille
# -EquipeELIPSS
#
# 2014:EnquêteNationalesurlesRessourcesdesJeunes(ENRJ)-INSEE,
# DREES-MinistèredelaSanté
# 3
#
#
# 2014:InformationetVieQuotidienne-Martinique-INSEE
#
# 2014:Enquêtemensuelledeconjonctureauprèsdesménages-INSEE
#
# 2014:Dynamiquesdemobilisation-vague3-EquipeELIPSS
#
# 2014:Attitudesàl'égarddesformesconjugalesalternatives-EquipeELIPSS
#
# 2014:Goûts,morales,groupessociaux-EquipeELIPSS
#
# 2014:Catégorisationsetconnaissancesordinairesdelasociété-Equipe
# ELIPSS
#
# 2014-2015:Enquêtenationalesurlasantéauprèsdesélèvesscolarisésen
# classedeCM2-DREES-MinistèredelaSanté
#
# 2014-2015:Patrimoine-INSEE
#
# 2015:Cosmopolitismeculturelchezlesjeunes-DEPS-Ministèredela
# Culture
#
# 2015:Diversitédesmodesdevieetpointesdeconsommationd'énergie-
# EquipeELIPSS
#
# 2015:Enquêtesurlesvaleurs,l'environnementetl'énergie-vague2-Equipe
# ELIPSS
#
# 2016:Enquêteannuelle-vague4-EquipeELIPSS
#
# 2016:Dynamiquesdemobilisation-vague13-EquipeELIPSS
#
# 2017:Enquêteannuelle-vague5-EquipeELIPSS
# Donnéesdi˙uséespardesorganismestiers
#
# 2000:pratiquessportive-MJS/INSEP
#
# depuis2011:CohorteELFE
#
# 2015:Statistiquessurlesressourcesetlesconditionsdevie-INSEE
#
# 2018:Baromètrenationaldespratiquessportives-CREDOC
# Exemplesdedonnéesétrangères
#
# 2006-2009-EuropeanHealthInterviewSurvey1-Eurostat
#
# 2013-2015-EuropeanHealthInterviewSurvey2-Eurostat
#
# 2017-Aspectsofdailylife-Istat|Enquêtelongitudinaleenpopulation
# généraleenItaliesurunéchantillondeprèsde50000personnes
#
# 2018-MonitoringtheFuture:AContinuingStudyofAmericanYouth-
# UniversityofMichigan.InstituteforSocialResearch.SurveyResearchCenter
# |EnquêterécurrenteetreprésentativesurlesélèvesÉtats-Uniensavantleur
# entréeaulycée.Lavaguede2018arécoltéplusde14000réponsesutilisables
# parniveaud'étude.Onytrouveplusieursquestionssurl'activitéphysique.
# 4
#
#
# Chaqueannéedepuis1975:NationalHealthInterviewSurvey-National
# CenterforHealthStatistics|États-Unis
# Àvenir
# 2020:Enquêtenationalesurlespratiquesphysiquesetsportives-INJEP
# 5
#
# Le4mars2020
# Enquêtesdelastatistiquepubliqueabordantlapra-
# tiquedusport
# Voiciunelistenonexhaustived'enquêtesdelastatistiquepubliquequiontabordé
# aumoinsàl'occasiond'unequestionlespratiquesphysiquesetsportives.Ils'agit
# d'unelisteévolutive,n'hésitezpasàenvoyeruncourrielàlouis.david@mshb.frpour
# suggérerunajout.
# DonnéesdisponiblesvialeportailQuételet-Progedo
#
# 1967:EnquêteLoisirs-INSEE
#
# 1974-1975:Enquêteemploidutemps-INSEE
#
# 1977:Lesstructuresdel'opinion-CEA
#
# 1978:Lesstructuresdel'opinion-CEA
#
# 1981-1982:Transport-INSEE
#
# 1985-1986:Emploidutemps-INSEE
#
# 1986:Lesstructuresdel'opinion-Jean-PierrePagès,DémosthèneAgra˝otis
#
# 1990-1992:AnalysedescomportementssexuelsenFrance-INED
#
# 1991:Lesstructuresdel'opinion-Jean-PierrePagès,DémosthèneAgra˝otis
#
# 1993-1994:Passageàl'âgeadulte-INED
#
# mai1995:Enquêtepermanentesurlesconditionsdeviedesménages,partie
# variable:vacancesàdomicile-INSEE
#
# 1995:Enquêteinterrégionaledesphénomènespolitiques-OIP
#
# 1996:Enquêteinterrégionaledesphénomènespolitiques-OIP
#
# janvier1997:Enquêtepermanentesurlesconditionsdeviedesménages,
# partievariable:travailetmodesdevie-INSEE
#
# 1997:Baromètrenucléaire-Jean-PierrePagès,DémosthèneAgra˝otis
#
# 1998:Comportementsfaceauxrisquesetàl'avenir-Enquêtecomplémentaire
# àl'enquêtePatrimoine-INSEE
#
# 1998:Handicaps,incapacités,dépendance:personnesvivanteninstitutions
# -INSEE
#
# 1998-1999:Emploidutemps-INSEE
#
# 1999:Handicaps,incapacités,dépendance:personnesvivantàdomicile-
# INSEE
#
# 2000:Baromètred'opiniondelaDREES-DREES-MinistèredelaSanté
# 1
#
#
# 2000:Handicaps,incapacités,dépendance:personnesvivanteninstitutions
# -INSEE
#
# octobre2000:Enquêtepermanentesurlesconditionsdeviedesménages,
# partievariable:lestransmissionsfamiliales-INSEE
#
# mai2001:Enquêtepermanentesurlesconditionsdeviedesménages,partie
# variable:comportementsvisàvisdelasanté-INSEE
#
# 2001:Baromètred'opiniondelaDREES-DREES-MinistèredelaSanté
#
# 2001:Enquêteinterrégionaledesphénomènespolitiques-OIP
#
# 2001:Handicaps,incapacités,dépendance:personnesenmilieucarcéral-
# INSEE
#
# 2001-2002:Enquêtenationalesurlasantéauprèsdesélèvesscolarisésen
# classedeCM2-DREES-MinistèredelaSanté
#
# 2002:Baromètred'opiniondelaDREES-DREES-MinistèredelaSanté
#
# octobre2002:Enquêtepermanentesurlesconditionsdeviedesménages,
# partievariable:vieassociative-INSEE
#
# 2002-2008:Universcultureldesenfantsetdesadolescents-DEPS
#
# mai2003:Enquêtepermanentesurlesconditionsdeviedesménages,partie
# variable:participationàlavieculturelleetsportive-INSEE
#
# 2003-2004:Enquêtenationalesurlasantéauprèsdesélèvesscolarisésen
# classede3ème-DREES-MinistèredelaSanté
#
# 2004:InformationetVieQuotidienne-INSEE
#
# 2004:Baromètred'opiniondelaDREES-DREES-MinistèredelaSanté
#
# octobre2004:Enquêtepermanentesurlesconditionsdeviedesménages,
# partievariable:vacances-INSEE
#
# 2004-2005:Enquêtenationalesurlasantéauprèsdesélèvesscolarisésen
# classedeCM2-DREES-MinistèredelaSanté
#
# 2005:Baromètred'opiniondelaDREES-DREES-MinistèredelaSanté
#
# 2005-2006:Enquêtenationalesurlasantéauprèsdesélèvesscolarisésen
# classedegrandesectiondematernelle-DREES-MinistèredelaSanté
#
# 2006:InformationetVieQuotidienne-Martinique-INSEE
#
# 2006:Baromètred'opiniondelaDREES-DREES-MinistèredelaSanté
#
# 2006-2007:Parcoursetpro˝lsdesmigrants-DREES-MinistèredelaSanté
#
# 2007:InternationalSocialSurveyProgramme-EnquêteFrance-Loisirset
# sportI-ISSP
#
# 2007:InformationetVieQuotidienne-Réunion-INSEE
#
# 2007:EnquêteEmploidanslesDOM-INSEE
#
# 2008:Trajectoiresetorigines,enquêtesurladiversitédespopulationsen
# 2
#
# France-INSEE
#
# 2008:Pratiquesculturellesdesfrançais-DEPS-MinistèredelaCulture
#
# 2008:InformationetVieQuotidienne-Guadeloupe-INSEE
#
# 2008:EnquêteHandicapSanté-Voletaidantsinformels-DREES-Ministère
# delaSanté
#
# 2008:EnquêteHandicapSanté-INSEE
#
# 2008:Enquêtenationaletransportsetdéplacements-SOeS-Ministèredes
# Transports
#
# 2008-2009:Enquêtenationalesurlasantéauprèsdesélèvesscolarisésen
# classede3ème-DREES-MinistèredelaSanté
#
# 2009:Statistiquessurlesressourcesetlesconditionsdevie-INSEE
#
# 2009-2010:Emploidutemps-INSEE
#
# 2010:EnquêtesurlesPratiquesPhysiquesetSportives-CNDS/Direction
# dessports-INPES-MEOS
#
# 2010:LavieassociativeenFrance-DREES-MinistèredelaSanté
#
# 2011:EnquêteLongitudinalesurl'IntégrationdesPrimo-Arrivants,vague2
# -DSED-Ministèredel'Intérieur
#
# 2011:InformationetVieQuotidienne-Réunion-INSEE
#
# 2011:InformationetVieQuotidienne-Guyane-INSEE
#
# 2011:InformationetVieQuotidienne-Mayotte-INSEE
#
# 2011:InternationalSocialSurveyProgramme-EnquêteFrance-SantéI-
# ISSP
#
# 2012:Enquêtesurlasantéetlaprotectionsociale(ESPS)-IRDES
#
# 2012:FrenchElectoralStudy-CEE
#
# 2012:Laviedeuxansaprèsundiagnosticdecancer-INCa-INSERM
#
# 2012:Statistiquessurlesressourcesetlesconditionsdevie-INSEE
#
# 2012-2013:Enquêtenationalesurlasantéauprèsdesélèvesscolarisésen
# classedegrandesectiondematernelle-DREES-MinistèredelaSanté
#
# 2013:Conditionsdeviedesétudiants(CdV)-Observatoiredelavieétu-
# diante
#
# 2013:EnquêteEmploiencontinu(versionFPR)-INSEE
#
# 2013:Dynamiquesdemobilisation:comprendrelaformationdeschoixélec-
# toraux-vague1-EquipeELIPSS
#
# 2013:Situationdecouple,intentionsdeféconditéetopinionssurlafamille
# -EquipeELIPSS
#
# 2014:EnquêteNationalesurlesRessourcesdesJeunes(ENRJ)-INSEE,
# DREES-MinistèredelaSanté
# 3
#
#
# 2014:InformationetVieQuotidienne-Martinique-INSEE
#
# 2014:Enquêtemensuelledeconjonctureauprèsdesménages-INSEE
#
# 2014:Dynamiquesdemobilisation-vague3-EquipeELIPSS
#
# 2014:Attitudesàl'égarddesformesconjugalesalternatives-EquipeELIPSS
#
# 2014:Goûts,morales,groupessociaux-EquipeELIPSS
#
# 2014:Catégorisationsetconnaissancesordinairesdelasociété-Equipe
# ELIPSS
#
# 2014-2015:Enquêtenationalesurlasantéauprèsdesélèvesscolarisésen
# classedeCM2-DREES-MinistèredelaSanté
#
# 2014-2015:Patrimoine-INSEE
#
# 2015:Cosmopolitismeculturelchezlesjeunes-DEPS-Ministèredela
# Culture
#
# 2015:Diversitédesmodesdevieetpointesdeconsommationd'énergie-
# EquipeELIPSS
#
# 2015:Enquêtesurlesvaleurs,l'environnementetl'énergie-vague2-Equipe
# ELIPSS
#
# 2016:Enquêteannuelle-vague4-EquipeELIPSS
#
# 2016:Dynamiquesdemobilisation-vague13-EquipeELIPSS
#
# 2017:Enquêteannuelle-vague5-EquipeELIPSS
# Donnéesdi˙uséespardesorganismestiers
#
# 2000:pratiquessportive-MJS/INSEP
#
# depuis2011:CohorteELFE
#
# 2015:Statistiquessurlesressourcesetlesconditionsdevie-INSEE
#
# 2018:Baromètrenationaldespratiquessportives-CREDOC
# Exemplesdedonnéesétrangères
#
# 2006-2009-EuropeanHealthInterviewSurvey1-Eurostat
#
# 2013-2015-EuropeanHealthInterviewSurvey2-Eurostat
#
# 2017-Aspectsofdailylife-Istat|Enquêtelongitudinaleenpopulation
# généraleenItaliesurunéchantillondeprèsde50000personnes
#
# 2018-MonitoringtheFuture:AContinuingStudyofAmericanYouth-
# UniversityofMichigan.InstituteforSocialResearch.SurveyResearchCenter
# |EnquêterécurrenteetreprésentativesurlesélèvesÉtats-Uniensavantleur
# entréeaulycée.Lavaguede2018arécoltéplusde14000réponsesutilisables
# parniveaud'étude.Onytrouveplusieursquestionssurl'activitéphysique.
# 4
#
#
# Chaqueannéedepuis1975:NationalHealthInterviewSurvey-National
# CenterforHealthStatistics|États-Unis
# Àvenir
# 2020:Enquêtenationalesurlespratiquesphysiquesetsportives-INJEP
# 5
#
# Le4mars2020
# Enquêtesdelastatistiquepubliqueabordantlapra-
# tiquedusport
# Voiciunelistenonexhaustived'enquêtesdelastatistiquepubliquequiontabordé
# aumoinsàl'occasiond'unequestionlespratiquesphysiquesetsportives.Ils'agit
# d'unelisteévolutive,n'hésitezpasàenvoyeruncourrielàlouis.david@mshb.frpour
# suggérerunajout.
# DonnéesdisponiblesvialeportailQuételet-Progedo
#
# 1967:EnquêteLoisirs-INSEE
#
# 1974-1975:Enquêteemploidutemps-INSEE
#
# 1977:Lesstructuresdel'opinion-CEA
#
# 1978:Lesstructuresdel'opinion-CEA
#
# 1981-1982:Transport-INSEE
#
# 1985-1986:Emploidutemps-INSEE
#
# 1986:Lesstructuresdel'opinion-Jean-PierrePagès,DémosthèneAgra˝otis
#
# 1990-1992:AnalysedescomportementssexuelsenFrance-INED
#
# 1991:Lesstructuresdel'opinion-Jean-PierrePagès,DémosthèneAgra˝otis
#
# 1993-1994:Passageàl'âgeadulte-INED
#
# mai1995:Enquêtepermanentesurlesconditionsdeviedesménages,partie
# variable:vacancesàdomicile-INSEE
#
# 1995:Enquêteinterrégionaledesphénomènespolitiques-OIP
#
# 1996:Enquêteinterrégionaledesphénomènespolitiques-OIP
#
# janvier1997:Enquêtepermanentesurlesconditionsdeviedesménages,
# partievariable:travailetmodesdevie-INSEE
#
# 1997:Baromètrenucléaire-Jean-PierrePagès,DémosthèneAgra˝otis
#
# 1998:Comportementsfaceauxrisquesetàl'avenir-Enquêtecomplémentaire
# àl'enquêtePatrimoine-INSEE
#
# 1998:Handicaps,incapacités,dépendance:personnesvivanteninstitutions
# -INSEE
#
# 1998-1999:Emploidutemps-INSEE
#
# 1999:Handicaps,incapacités,dépendance:personnesvivantàdomicile-
# INSEE
#
# 2000:Baromètred'opiniondelaDREES-DREES-MinistèredelaSanté
# 1
#
#
# 2000:Handicaps,incapacités,dépendance:personnesvivanteninstitutions
# -INSEE
#
# octobre2000:Enquêtepermanentesurlesconditionsdeviedesménages,
# partievariable:lestransmissionsfamiliales-INSEE
#
# mai2001:Enquêtepermanentesurlesconditionsdeviedesménages,partie
# variable:comportementsvisàvisdelasanté-INSEE
#
# 2001:Baromètred'opiniondelaDREES-DREES-MinistèredelaSanté
#
# 2001:Enquêteinterrégionaledesphénomènespolitiques-OIP
#
# 2001:Handicaps,incapacités,dépendance:personnesenmilieucarcéral-
# INSEE
#
# 2001-2002:Enquêtenationalesurlasantéauprèsdesélèvesscolarisésen
# classedeCM2-DREES-MinistèredelaSanté
#
# 2002:Baromètred'opiniondelaDREES-DREES-MinistèredelaSanté
#
# octobre2002:Enquêtepermanentesurlesconditionsdeviedesménages,
# partievariable:vieassociative-INSEE
#
# 2002-2008:Universcultureldesenfantsetdesadolescents-DEPS
#
# mai2003:Enquêtepermanentesurlesconditionsdeviedesménages,partie
# variable:participationàlavieculturelleetsportive-INSEE
#
# 2003-2004:Enquêtenationalesurlasantéauprèsdesélèvesscolarisésen
# classede3ème-DREES-MinistèredelaSanté
#
# 2004:InformationetVieQuotidienne-INSEE
#
# 2004:Baromètred'opiniondelaDREES-DREES-MinistèredelaSanté
#
# octobre2004:Enquêtepermanentesurlesconditionsdeviedesménages,
# partievariable:vacances-INSEE
#
# 2004-2005:Enquêtenationalesurlasantéauprèsdesélèvesscolarisésen
# classedeCM2-DREES-MinistèredelaSanté
#
# 2005:Baromètred'opiniondelaDREES-DREES-MinistèredelaSanté
#
# 2005-2006:Enquêtenationalesurlasantéauprèsdesélèvesscolarisésen
# classedegrandesectiondematernelle-DREES-MinistèredelaSanté
#
# 2006:InformationetVieQuotidienne-Martinique-INSEE
#
# 2006:Baromètred'opiniondelaDREES-DREES-MinistèredelaSanté
#
# 2006-2007:Parcoursetpro˝lsdesmigrants-DREES-MinistèredelaSanté
#
# 2007:InternationalSocialSurveyProgramme-EnquêteFrance-Loisirset
# sportI-ISSP
#
# 2007:InformationetVieQuotidienne-Réunion-INSEE
#
# 2007:EnquêteEmploidanslesDOM-INSEE
#
# 2008:Trajectoiresetorigines,enquêtesurladiversitédespopulationsen
# 2
#
# France-INSEE
#
# 2008:Pratiquesculturellesdesfrançais-DEPS-MinistèredelaCulture
#
# 2008:InformationetVieQuotidienne-Guadeloupe-INSEE
#
# 2008:EnquêteHandicapSanté-Voletaidantsinformels-DREES-Ministère
# delaSanté
#
# 2008:EnquêteHandicapSanté-INSEE
#
# 2008:Enquêtenationaletransportsetdéplacements-SOeS-Ministèredes
# Transports
#
# 2008-2009:Enquêtenationalesurlasantéauprèsdesélèvesscolarisésen
# classede3ème-DREES-MinistèredelaSanté
#
# 2009:Statistiquessurlesressourcesetlesconditionsdevie-INSEE
#
# 2009-2010:Emploidutemps-INSEE
#
# 2010:EnquêtesurlesPratiquesPhysiquesetSportives-CNDS/Direction
# dessports-INPES-MEOS
#
# 2010:LavieassociativeenFrance-DREES-MinistèredelaSanté
#
# 2011:EnquêteLongitudinalesurl'IntégrationdesPrimo-Arrivants,vague2
# -DSED-Ministèredel'Intérieur
#
# 2011:InformationetVieQuotidienne-Réunion-INSEE
#
# 2011:InformationetVieQuotidienne-Guyane-INSEE
#
# 2011:InformationetVieQuotidienne-Mayotte-INSEE
#
# 2011:InternationalSocialSurveyProgramme-EnquêteFrance-SantéI-
# ISSP
#
# 2012:Enquêtesurlasantéetlaprotectionsociale(ESPS)-IRDES
#
# 2012:FrenchElectoralStudy-CEE
#
# 2012:Laviedeuxansaprèsundiagnosticdecancer-INCa-INSERM
#
# 2012:Statistiquessurlesressourcesetlesconditionsdevie-INSEE
#
# 2012-2013:Enquêtenationalesurlasantéauprèsdesélèvesscolarisésen
# classedegrandesectiondematernelle-DREES-MinistèredelaSanté
#
# 2013:Conditionsdeviedesétudiants(CdV)-Observatoiredelavieétu-
# diante
#
# 2013:EnquêteEmploiencontinu(versionFPR)-INSEE
#
# 2013:Dynamiquesdemobilisation:comprendrelaformationdeschoixélec-
# toraux-vague1-EquipeELIPSS
#
# 2013:Situationdecouple,intentionsdeféconditéetopinionssurlafamille
# -EquipeELIPSS
#
# 2014:EnquêteNationalesurlesRessourcesdesJeunes(ENRJ)-INSEE,
# DREES-MinistèredelaSanté
# 3
#
#
# 2014:InformationetVieQuotidienne-Martinique-INSEE
#
# 2014:Enquêtemensuelledeconjonctureauprèsdesménages-INSEE
#
# 2014:Dynamiquesdemobilisation-vague3-EquipeELIPSS
#
# 2014:Attitudesàl'égarddesformesconjugalesalternatives-EquipeELIPSS
#
# 2014:Goûts,morales,groupessociaux-EquipeELIPSS
#
# 2014:Catégorisationsetconnaissancesordinairesdelasociété-Equipe
# ELIPSS
#
# 2014-2015:Enquêtenationalesurlasantéauprèsdesélèvesscolarisésen
# classedeCM2-DREES-MinistèredelaSanté
#
# 2014-2015:Patrimoine-INSEE
#
# 2015:Cosmopolitismeculturelchezlesjeunes-DEPS-Ministèredela
# Culture
#
# 2015:Diversitédesmodesdevieetpointesdeconsommationd'énergie-
# EquipeELIPSS
#
# 2015:Enquêtesurlesvaleurs,l'environnementetl'énergie-vague2-Equipe
# ELIPSS
#
# 2016:Enquêteannuelle-vague4-EquipeELIPSS
#
# 2016:Dynamiquesdemobilisation-vague13-EquipeELIPSS
#
# 2017:Enquêteannuelle-vague5-EquipeELIPSS
# Donnéesdi˙uséespardesorganismestiers
#
# 2000:pratiquessportive-MJS/INSEP
#
# depuis2011:CohorteELFE
#
# 2015:Statistiquessurlesressourcesetlesconditionsdevie-INSEE
#
# 2018:Baromètrenationaldespratiquessportives-CREDOC
# Exemplesdedonnéesétrangères
#
# 2006-2009-EuropeanHealthInterviewSurvey1-Eurostat
#
# 2013-2015-EuropeanHealthInterviewSurvey2-Eurostat
#
# 2017-Aspectsofdailylife-Istat|Enquêtelongitudinaleenpopulation
# généraleenItaliesurunéchantillondeprèsde50000personnes
#
# 2018-MonitoringtheFuture:AContinuingStudyofAmericanYouth-
# UniversityofMichigan.InstituteforSocialResearch.SurveyResearchCenter
# |EnquêterécurrenteetreprésentativesurlesélèvesÉtats-Uniensavantleur
# entréeaulycée.Lavaguede2018arécoltéplusde14000réponsesutilisables
# parniveaud'étude.Onytrouveplusieursquestionssurl'activitéphysique.
# 4
#
#
# Chaqueannéedepuis1975:NationalHealthInterviewSurvey-National
# CenterforHealthStatistics|États-Unis
# Àvenir
# 2020:Enquêtenationalesurlespratiquesphysiquesetsportives-INJEP
# 5
